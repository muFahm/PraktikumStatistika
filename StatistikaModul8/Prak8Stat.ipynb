# %% [markdown]
# Import Library yang dibutuhkan

# %%
import pandas as pd
import pandas.plotting
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier,export_graphviz
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

# %% [markdown]
# # Latihan1

# %% [markdown]
# Memasukkan Dataset

# %%
data_fahmi = pd.read_csv('houseprice.csv', sep=";")
data_fahmi.head(5)
# Out:
#     Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0  114300  1790         2          2       2    No         East
# 1  114200  2030         4          2       3    No         East
# 2  114800  1740         3          2       1    No         East
# 3   94700  1980         3          2       3    No         East
# 4  119800  2130         3          3       3    No         East

# %% [markdown]
# Boxplot dari harga rumah/Price

# %%
col_list=['Price']
numhouse = data_fahmi[data_fahmi.columns[data_fahmi.columns.isin(col_list)]]
plt.figure(figsize=(10,5))
numhouse.boxplot(sym='r*', grid=False)
plt.show()

# %% [markdown]
# Histogram dari Price

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
data_fahmi['Price'].plot.hist(bins=10, title='Price')
plt.show()

# %% [markdown]
# Scatter dari Price

# %%
col_list=['Price', 'SqFt']
numhouse = data_fahmi[data_fahmi.columns[data_fahmi.columns.isin(col_list)]]
numhouse.plot.scatter(x='SqFt', y='Price')
# Out:
# <Axes: xlabel='SqFt', ylabel='Price'>

# %% [markdown]
# Group Boxplot Berdasarkan Bedrooms

# %%
col_list=['Price', 'Bedrooms']
numhouse = data_fahmi[data_fahmi.columns[data_fahmi.columns.isin(col_list)]]
plt.figure(figsize=(15,5))
numhouse.boxplot(by='Bedrooms')
plt.show()

# %% [markdown]
# # Latihan2

# %% [markdown]
# Scatter Plot Harga Rumah Berdasarkan Bedrooms

# %%
col_list=['Price', 'Bedrooms']
numhouse = data_fahmi[data_fahmi.columns[data_fahmi.columns.isin(col_list)]]
numhouse.plot.scatter(x='Bedrooms', y='Price')
# Out:
# <Axes: xlabel='Bedrooms', ylabel='Price'>

# %% [markdown]
# Scatter Plot Harga Rumah berdasarkan Bathrooms

# %%
col_list=['Price', 'Bathrooms']
numhouse = data_fahmi[data_fahmi.columns[data_fahmi.columns.isin(col_list)]]
numhouse.plot.scatter(x='Bathrooms', y='Price')
# Out:
# <Axes: xlabel='Bathrooms', ylabel='Price'>

# %% [markdown]
# Grouped Boxplot berdasarkan Bathrooms dengan Price sebagai perbandingannya

# %%
col_list=['Price', 'Bathrooms']
numhouse = data_fahmi[data_fahmi.columns[data_fahmi.columns.isin(col_list)]]
plt.figure(figsize=(15,5))
numhouse.boxplot(by='Bathrooms')
plt.show()
